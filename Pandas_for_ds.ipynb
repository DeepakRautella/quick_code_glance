# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # Pandas command regardings Dataset and Series

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp'

# %%
df=pd.read_csv(r'C:\Users\hp\Downloads\Zomato.csv')
#or
#df_=pd.read_csv('C:\Users\hp\Downloads\Zomato.csv')  #if error occur using read_csv

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['url'])
# Out:
# pandas.core.series.Series

# %%
df.sample(5)
# Out:
#                                                      url  \
# 14121  https://www.zomato.com/bangalore/unlock-the-re...
# 15165  https://www.zomato.com/bangalore/bon-sante-bri...
# 9688   https://www.zomato.com/bangalore/ruchis-foodie...
# 14936  https://www.zomato.com/bangalore/popat-indiran...
# 42477  https://www.zomato.com/bangalore/fullyfilled-i...
#
#                                                  address  \
# 14121  Keys Hotel, Electronic City, Bangalore Opposit...
# 15165  6, Resthouse Road, Off Brigade Road, Brigade R...
# 9688   House 107, 13th A Cross, 2nd Stage, BTM, Banga...
# 14936  73/1, Shamanna Gowda Layout, 1st Main Channel ...
# 42477  #68, G1, 10th Main, 4th Cross, Indiranagar, Be...
#
#                         name online_order book_table    rate  votes  \
# 14121  Unlock - The Restobar           No         No   3.8/5     27
# 15165              Bon Sante           No         No   3.6/5    104
# ...

# %%
#preview of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
#describe gives numeric dataset describtion
df.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
#DataFrame.select_dtypes(include=None, exclude=None)
#Return a subset of the DataFrame’s columns based on the column dtypes.
df.select_dtypes(include='int64')
# Out:
#        votes
# 0        775
# 1        787
# 2        918
# 3         88
# 4        166
# ...      ...
# 51712     27
# 51713      0
# 51714      0
# 51715    236
# 51716     13
#
# [51717 rows x 1 columns]

# %%
df.select_dtypes(include='object')
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
#property DataFrame.values[source]
#Return a Numpy representation of the DataFrame.
df.values
# Out:
# array([['https://www.zomato.com/bangalore/jalsa-banashankari?context=eyJzZSI6eyJlIjpbNTg2OTQsIjE4Mzc1NDc0IiwiNTkwOTAiLCIxODM4Mjk0NCIsIjE4MjI0Njc2IiwiNTkyODkiLCIxODM3MzM4NiJdLCJ0IjoiUmVzdGF1cmFudHMgaW4gQmFuYXNoYW5rYXJpIHNlcnZpbmcgQnVmZmV0In19',
#         '942, 21st Main Road, 2nd Stage, Banashankari, Bangalore',
#         'Jalsa', ..., '[]', 'Buffet', 'Banashankari'],
#        ['https://www.zomato.com/bangalore/spice-elephant-banashankari?context=eyJzZSI6eyJlIjpbIjU4Njk0IiwxODM3NTQ3NCwiNTkwOTAiLCIxODM4Mjk0NCIsIjE4MjI0Njc2IiwiNTkyODkiLCIxODM3MzM4NiJdLCJ0IjoiUmVzdGF1cmFudHMgaW4gQmFuYXNoYW5rYXJpIHNlcnZpbmcgQnVmZmV0In19',
#         '2nd Floor, 80 Feet Road, Near Big Bazaar, 6th Block, Kathriguppe, 3rd Stage, Banashankari, Bangalore',
#         'Spice Elephant', ..., '[]', 'Buffet', 'Banashankari'],
# ...

# %%
#convert dataframe to numpy
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
#index range same as shape
df.index
# Out:
# RangeIndex(start=0, stop=51717, step=1)

# %%
#axes[source]
#Return a list representing the axes of the DataFrame.
df.axes
# Out:
# [RangeIndex(start=0, stop=51717, step=1),
#  Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#         'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#         'approx_cost(for two people)', 'reviews_list', 'menu_item',
#         'listed_in(type)', 'listed_in(city)'],
#        dtype='object')]

# %%
#dimension
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 879189

# %%
#columns
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.shape    #(rows,columns)
# Out:
# (51717, 17)

# %%
df.shape[0]
# Out:
# 51717

# %%
df.shape[1]
# Out:
# 17

# %%
#DataFrame.memory_usage(index=True, deep=False)
df.memory_usage(index=False)
# Out:
# url                            413736
# address                        413736
# name                           413736
# online_order                   413736
# book_table                     413736
# rate                           413736
# votes                          413736
# phone                          413736
# location                       413736
# rest_type                      413736
# dish_liked                     413736
# cuisines                       413736
# approx_cost(for two people)    413736
# reviews_list                   413736
# menu_item                      413736
# listed_in(type)                413736
# listed_in(city)                413736
# dtype: int64

# %%
#pandas.DataFrame.astype
#DataFrame.astype(dtype, copy=True, errors='raise')
#Cast a pandas object to a specified dtype dtype.
df=df.astype({'votes':'float'},copy=True)

# %%
df.dtypes
# Out:
# url                             object
# address                         object
# name                            object
# online_order                    object
# book_table                      object
# rate                            object
# votes                          float64
# phone                           object
# location                        object
# rest_type                       object
# dish_liked                      object
# cuisines                        object
# approx_cost(for two people)     object
# reviews_list                    object
# menu_item                       object
# listed_in(type)                 object
# listed_in(city)                 object
# dtype: object

# %%
#yto fetch single column it will convert automatically as series
df['url']
# Out:
# 0        https://www.zomato.com/bangalore/jalsa-banasha...
# 1        https://www.zomato.com/bangalore/spice-elephan...
# 2        https://www.zomato.com/SanchurroBangalore?cont...
# 3        https://www.zomato.com/bangalore/addhuri-udupi...
# 4        https://www.zomato.com/bangalore/grand-village...
#                                ...
# 51712    https://www.zomato.com/bangalore/best-brews-fo...
# 51713    https://www.zomato.com/bangalore/vinod-bar-and...
# 51714    https://www.zomato.com/bangalore/plunge-sherat...
# 51715    https://www.zomato.com/bangalore/chime-sherato...
# 51716    https://www.zomato.com/bangalore/the-nest-the-...
# Name: url, Length: 51717, dtype: object

# %%
type(df['url'])
# Out:
# pandas.core.series.Series

# %%
#convert series dataset into dataframe
df[['url']]
# Out:
#                                                      url
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
# [51717 rows x 1 columns]

# %%
type(df[['url']])
# Out:
# pandas.core.frame.DataFrame

# %%
#fetch multiple columns

df['url','address','votes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('url', 'address', 'votes')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#error because single [] fetch dcolumn as series, so while fetching multiple columns we need to fetch it as dataset for that we
# will use [['column_name_1','column_name_2',.......]]

# %%
df[['url','address','votes']]
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  votes
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...    775
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...    787
# 2      1112, Next to KIMS Medical College, 17th Cross...    918
# ...

# %%
#fetching rows using index number
#iloc func: Purely integer-location based indexing for selection by position.

# %%
df.iloc[0]
# Out:
# url                            https://www.zomato.com/bangalore/jalsa-banasha...
# address                        942, 21st Main Road, 2nd Stage, Banashankari, ...
# name                                                                       Jalsa
# online_order                                                                 Yes
# book_table                                                                   Yes
# rate                                                                       4.1/5
# votes                                                                        775
# phone                                             080 42297555\r\n+91 9743772233
# location                                                            Banashankari
# rest_type                                                          Casual Dining
# dish_liked                     Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# cuisines                                          North Indian, Mughlai, Chinese
# ...

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
#fetching rows as dataframe
df.iloc[[0]]
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
#
#                                              address   name online_order  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
#
#   book_table   rate  votes                           phone      location  \
# 0        Yes  4.1/5    775  080 42297555\r\n+91 9743772233  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari

# %%
#multiple rows
df.iloc[[0,32]]    #fenching index if no pattern
# Out:
#                                                   url  \
# 0   https://www.zomato.com/bangalore/jalsa-banasha...
# 32  https://www.zomato.com/bangalore/sweet-truth-b...
#
#                                               address         name  \
# 0   942, 21st Main Road, 2nd Stage, Banashankari, ...        Jalsa
# 32  101 Ground Floor, Manjunatha Complex, 22nd Mai...  Sweet Truth
#
#    online_order book_table   rate  votes                           phone  \
# 0           Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 32          Yes         No  3.9/5     35                  +91 7710055553
#
#         location      rest_type  \
# 0   Banashankari  Casual Dining
# 32  Banashankari       Delivery
#
#                                            dish_liked  \
# 0   Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 32                                                NaN
#
#                           cuisines approx_cost(for two people)  \
# ...

# %%
#fetching rows as continious
df.iloc[1:10]
# Out:
#                                                  url  \
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
# 5  https://www.zomato.com/bangalore/timepass-dinn...
# 6  https://www.zomato.com/bangalore/rosewood-inte...
# 7  https://www.zomato.com/bangalore/onesta-banash...
# 8  https://www.zomato.com/bangalore/penthouse-caf...
# 9  https://www.zomato.com/bangalore/smacznego-ban...
#
#                                              address  \
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2  1112, Next to KIMS Medical College, 17th Cross...
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# 5  37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...
# 6  19/1, New Timberyard Layout, Beside Satellite ...
# 7  2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
# ...

# %%
df.iloc[1:10:2]
# Out:
#                                                  url  \
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 5  https://www.zomato.com/bangalore/timepass-dinn...
# 7  https://www.zomato.com/bangalore/onesta-banash...
# 9  https://www.zomato.com/bangalore/smacznego-ban...
#
#                                              address                   name  \
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 5  37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...        Timepass Dinner
# 7  2469, 3rd Floor, 24th Cross, Opposite BDA Comp...                 Onesta
# 9  2470, 21 Main Road, 25th Cross, Banashankari, ...              Smacznego
#
#   online_order book_table   rate  votes                             phone  \
# 1          Yes         No  4.1/5    787                      080 41714161
# ...

# %%
#fetching column using iloc

df.iloc[:,[4,5,10]]  #[rows index start: row index end:increment , column index start:column index end:increment]
# Out:
#       book_table    rate                                         dish_liked
# 0            Yes   4.1/5  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1             No   4.1/5  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2             No   3.8/5  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3             No   3.7/5                                        Masala Dosa
# 4             No   3.8/5                                Panipuri, Gol Gappe
# ...          ...     ...                                                ...
# 51712         No  3.6 /5                                                NaN
# 51713         No     NaN                                                NaN
# 51714         No     NaN                                                NaN
# 51715        Yes  4.3 /5                       Cocktails, Pizza, Buttermilk
# 51716         No  3.4 /5                                                NaN
#
# [51717 rows x 3 columns]

# %%
df.iloc[[2,5,9],[3,4,6]]
# Out:
#   online_order book_table  votes
# 2          Yes         No    918
# 5          Yes         No    286
# 9          Yes         No    504

# %%
#loc usage
#Access a group of rows and columns by label(s) or a boolean array.
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
#loc used by default index  or there defined name
df.loc[0]
# Out:
# url                            https://www.zomato.com/bangalore/jalsa-banasha...
# address                        942, 21st Main Road, 2nd Stage, Banashankari, ...
# name                                                                       Jalsa
# online_order                                                                 Yes
# book_table                                                                   Yes
# rate                                                                       4.1/5
# votes                                                                        775
# phone                                             080 42297555\r\n+91 9743772233
# location                                                            Banashankari
# rest_type                                                          Casual Dining
# dish_liked                     Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# cuisines                                          North Indian, Mughlai, Chinese
# ...

# %%
#loc used by default index  or there defined name   
df.loc[0:3:1,['url','phone']]     #if
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
#
#                             phone
# 0  080 42297555\r\n+91 9743772233
# 1                    080 41714161
# 2                  +91 9663487993
# 3                  +91 9620009302

# %%
df.loc[[0,3,1],['url','phone']]
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                             phone
# 0  080 42297555\r\n+91 9743772233
# 3                  +91 9620009302
# 1                    080 41714161

# %%
#note if index number is in sequences no list required  ex:  df.loc[:: ,::]
# but if not in sequense but in seperate name or index   ex: df.loc[[1,4,7],['age','name'.'category']]

# %% [markdown]
# # filtering Dataframe on condition

# %%
df.head(3)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
#
#                                              address             name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...            Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...   Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...  San Churro Cafe
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
# 2          Yes         No  3.8/5    918                  +91 9663487993
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
#
# ...

# %%
#1 condition
mask=df['votes']>=1000           #bool series output format

# %%
#2 we need data where true    put condition on dataframe
df[mask]
# Out:
#                                                      url  \
# 7      https://www.zomato.com/bangalore/onesta-banash...
# 37     https://www.zomato.com/bangalore/szechuan-drag...
# 38     https://www.zomato.com/bangalore/empire-restau...
# 44     https://www.zomato.com/bangalore/onesta-banash...
# 54     https://www.zomato.com/bangalore/roving-feast-...
# ...                                                  ...
# 51696  https://www.zomato.com/bangalore/the-irish-hou...
# 51697  https://www.zomato.com/bangalore/shizusan-shop...
# 51699  https://www.zomato.com/bangalore/harrys-bar-ca...
# 51700  https://www.zomato.com/bangalore/bar-bar-white...
# 51702  https://www.zomato.com/bangalore/pablos-gastro...
#
#                                                  address  \
# 7      2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
# 37     8, 2nd Floor, 1st Main, Arush Trapeze, Mount J...
# 38     4, Opposite NMKRV College, 21st C Cross Road, ...
# ...

# %%
df[df['votes']>=1000].shape
# Out:
# (3649, 17)

# %%
#more than one condition
mask1=df['votes']>=1000
mask2=df['online_order']=='Yes'

# %%
df[mask1 & mask2]           #mask is bool series so we will use bitwise & not bool and
# Out:
#                                                      url  \
# 7      https://www.zomato.com/bangalore/onesta-banash...
# 37     https://www.zomato.com/bangalore/szechuan-drag...
# 38     https://www.zomato.com/bangalore/empire-restau...
# 44     https://www.zomato.com/bangalore/onesta-banash...
# 65     https://www.zomato.com/bangalore/kabab-magic-b...
# ...                                                  ...
# 51688  https://www.zomato.com/bangalore/ji-hazoor-whi...
# 51694  https://www.zomato.com/WhitefieldSocial?contex...
# 51695  https://www.zomato.com/bangalore/the-whitefiel...
# 51697  https://www.zomato.com/bangalore/shizusan-shop...
# 51699  https://www.zomato.com/bangalore/harrys-bar-ca...
#
#                                                  address  \
# 7      2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
# 37     8, 2nd Floor, 1st Main, Arush Trapeze, Mount J...
# 38     4, Opposite NMKRV College, 21st C Cross Road, ...
# ...

# %%
mask1=df['votes']>=1000
mask2=df['online_order']=='Yes'
mask3=df['book_table']=='Yes'
mask4=df['location']=='Banashankari'

# %%
df[mask1 & mask2 & mask3 & mask4]
# Out:
#                                                      url  \
# 7      https://www.zomato.com/bangalore/onesta-banash...
# 44     https://www.zomato.com/bangalore/onesta-banash...
# 465    https://www.zomato.com/bangalore/vinnys-banash...
# 557    https://www.zomato.com/bangalore/onesta-banash...
# 560    https://www.zomato.com/bangalore/vinnys-banash...
# 2584   https://www.zomato.com/bangalore/onesta-banash...
# 2625   https://www.zomato.com/bangalore/vinnys-banash...
# 3474   https://www.zomato.com/bangalore/vinnys-banash...
# 19586  https://www.zomato.com/bangalore/onesta-banash...
# 19660  https://www.zomato.com/bangalore/vinnys-banash...
# 21314  https://www.zomato.com/bangalore/vinnys-banash...
#
#                                                  address     name  \
# 7      2469, 3rd Floor, 24th Cross, Opposite BDA Comp...   Onesta
# 44     2469, 3rd Floor, 24th Cross, Opposite BDA Comp...   Onesta
# 465    2467, 24th Cross, 2nd Stage, Banashankari, Ban...  Vinny's
# ...

# %% [markdown]
# # value count func
# only for categorical columns --frequencies
# only work in series

# %%
df.head(3)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
#
#                                              address             name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...            Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...   Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...  San Churro Cafe
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
# 2          Yes         No  3.8/5    918                  +91 9663487993
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
#
# ...

# %%
df['location'].value_counts()
# Out:
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
#                          ...
# West Bangalore              6
# Yelahanka                   6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: location, Length: 93, dtype: int64

# %%
df.online_order.value_counts()
# Out:
# Yes    30444
# No     21273
# Name: online_order, dtype: int64

# %%
df.book_table.value_counts()
# Out:
# No     45268
# Yes     6449
# Name: book_table, dtype: int64

# %% [markdown]
# # Plot Function

# %%
import matplotlib.pyplot as plt
df['location'].value_counts().plot(kind='bar',figsize=(30,30))
# Out:
# <AxesSubplot:>

# %%
#for limited 
df['location'].value_counts().head(7).plot(kind='bar',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
#for limited 
df['location'].value_counts().head(7).plot(kind='barh',figsize=(5,10))
# Out:
# <AxesSubplot:>

# %%
df['location'].value_counts().head().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='location'>

# %%
df['votes'].plot(kind='hist',bins=15)     #for hist numerical values
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['votes'].plot(kind='kde')            #kenral density plot  only for numerical category
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Series commands

# %%
#first index     #second values
my_series=df['location'].value_counts()

# %%
my_series
# Out:
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
#                          ...
# West Bangalore              6
# Yelahanka                   6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: location, Length: 93, dtype: int64

# %%
my_series.index
# Out:
# Index(['BTM', 'HSR', 'Koramangala 5th Block', 'JP Nagar', 'Whitefield',
#        'Indiranagar', 'Jayanagar', 'Marathahalli', 'Bannerghatta Road',
#        'Bellandur', 'Electronic City', 'Koramangala 1st Block', 'Brigade Road',
#        'Koramangala 7th Block', 'Koramangala 6th Block', 'Sarjapur Road',
#        'Ulsoor', 'Koramangala 4th Block', 'MG Road', 'Banashankari',
#        'Kalyan Nagar', 'Richmond Road', 'Frazer Town', 'Malleshwaram',
#        'Basavanagudi', 'Residency Road', 'Banaswadi', 'Brookefield',
#        'New BEL Road', 'Kammanahalli', 'Rajajinagar', 'Church Street',
#        'Lavelle Road', 'Shanti Nagar', 'Shivajinagar', 'Domlur',
#        'Cunningham Road', 'Old Airport Road', 'Ejipura', 'Commercial Street',
#        'St. Marks Road', 'Koramangala 8th Block', 'Vasanth Nagar',
#        'Jeevan Bhima Nagar', 'Wilson Garden', 'Bommanahalli',
#        'Koramangala 3rd Block', 'Kumaraswamy Layout', 'Thippasandra',
# ...

# %%
my_series.values
# Out:
# array([5124, 2523, 2504, 2235, 2144, 2083, 1926, 1846, 1630, 1286, 1258,
#        1238, 1218, 1181, 1156, 1065, 1023, 1017,  918,  906,  853,  812,
#         727,  725,  684,  675,  664,  658,  649,  648,  591,  569,  529,
#         511,  499,  496,  491,  446,  439,  370,  352,  320,  295,  272,
#         246,  238,  216,  195,  194,  191,  187,  165,  161,  155,  153,
#         151,  139,  126,  119,  117,  113,  107,  102,  102,  101,   90,
#          80,   80,   76,   63,   53,   48,   44,   38,   34,   32,   27,
#          27,   22,   22,   19,   18,   17,   14,   14,    9,    9,    8,
#           6,    6,    3,    2,    1], dtype=int64)

# %%
my_series.head()
# Out:
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
# Name: location, dtype: int64

# %%
my_series.tail()
# Out:
# West Bangalore          6
# Yelahanka               6
# Jakkur                  3
# Rajarajeshwari Nagar    2
# Peenya                  1
# Name: location, dtype: int64

# %%
my_series['Yelahanka']
# Out:
# 6

# %%
my_series_1=df['location'].value_counts()
my_series_2=df['listed_in(city)'].value_counts()

# %%
my_series_2
# Out:
# BTM                      3279
# Koramangala 7th Block    2938
# Koramangala 5th Block    2836
# Koramangala 4th Block    2779
# Koramangala 6th Block    2623
# Jayanagar                2371
# JP Nagar                 2096
# Indiranagar              1860
# Church Street            1827
# MG Road                  1811
# Brigade Road             1769
# Lavelle Road             1744
# HSR                      1741
# Marathahalli             1659
# Residency Road           1620
# Whitefield               1620
# Bannerghatta Road        1617
# Brookefield              1518
# Old Airport Road         1425
# Kammanahalli             1329
# Kalyan Nagar             1309
# Basavanagudi             1266
# Sarjapur Road            1261
# Electronic City          1229
# Bellandur                1227
# Frazer Town              1185
# Malleshwaram             1096
# Rajajinagar              1079
# Banashankari              863
# New BEL Road              740
# Name: listed_in(city), dtype: int64

# %%
my_series_1
# Out:
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
#                          ...
# West Bangalore              6
# Yelahanka                   6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: location, Length: 93, dtype: int64

# %%
my_series_1+my_series_2      #combine two series with common index   #any mathmethical operation can be done
# Out:
# BTM                  8403.0
# Banashankari         1769.0
# Banaswadi               NaN
# Bannerghatta Road    3247.0
# Basavanagudi         1950.0
#                       ...
# West Bangalore          NaN
# Whitefield           3764.0
# Wilson Garden           NaN
# Yelahanka               NaN
# Yeshwantpur             NaN
# Length: 93, dtype: float64

# %% [markdown]
# # Sort values
# applicable for series as well as dataframe

# %%
(my_series_1+my_series_2).sort_values()    #by default sort ascending and on last nan values
# Out:
# New BEL Road        1389.0
# Rajajinagar         1670.0
# Banashankari        1769.0
# Malleshwaram        1821.0
# Old Airport Road    1871.0
#                      ...
# Vijay Nagar            NaN
# West Bangalore         NaN
# Wilson Garden          NaN
# Yelahanka              NaN
# Yeshwantpur            NaN
# Length: 93, dtype: float64

# %%
df['location'].value_counts().sort_values()
# Out:
# Peenya                      1
# Rajarajeshwari Nagar        2
# Jakkur                      3
# Yelahanka                   6
# West Bangalore              6
#                          ...
# Whitefield               2144
# JP Nagar                 2235
# Koramangala 5th Block    2504
# HSR                      2523
# BTM                      5124
# Name: location, Length: 93, dtype: int64

# %%
df['location'].value_counts().sort_values(ascending=False)
# Out:
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
#                          ...
# West Bangalore              6
# Yelahanka                   6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: location, Length: 93, dtype: int64

# %%
df['location'].value_counts().sort_values(ascending=False).head()
# Out:
# BTM                      5124
# HSR                      2523
# Koramangala 5th Block    2504
# JP Nagar                 2235
# Whitefield               2144
# Name: location, dtype: int64

# %% [markdown]
# # sorting inside a dataframe

# %%
df.sort_values('votes',ascending=False,inplace=True) #for permanent changes in dataframe keep inplace true otherwise bydefault false

# %%
df.head()
# Out:
#                                                      url  \
# 49170  https://www.zomato.com/bangalore/byg-brewski-b...
# 50059  https://www.zomato.com/bangalore/byg-brewski-b...
# 49627  https://www.zomato.com/bangalore/byg-brewski-b...
# 3921   https://www.zomato.com/bangalore/byg-brewski-b...
# 4801   https://www.zomato.com/bangalore/byg-brewski-b...
#
#                                           address  \
# 49170  Behind MK Retail, Sarjapur Road, Bangalore
# 50059  Behind MK Retail, Sarjapur Road, Bangalore
# 49627  Behind MK Retail, Sarjapur Road, Bangalore
# 3921   Behind MK Retail, Sarjapur Road, Bangalore
# 4801   Behind MK Retail, Sarjapur Road, Bangalore
#
#                               name online_order book_table    rate  votes  \
# 49170  Byg Brewski Brewing Company          Yes        Yes  4.9 /5  16832
# 50059  Byg Brewski Brewing Company          Yes        Yes  4.9 /5  16832
# 49627  Byg Brewski Brewing Company          Yes        Yes  4.9 /5  16832
# ...

# %% [markdown]
# # multiple columns sorting

# %%
df.sort_values(['votes','location'])
# Out:
#                                                      url  \
# 27455  https://www.zomato.com/bangalore/caramel-shake...
# 27447  https://www.zomato.com/bangalore/tentacles-btm...
# 27315  https://www.zomato.com/bangalore/hotel-vkm-btm...
# 27414  https://www.zomato.com/bangalore/anvar-bhais-b...
# 27321  https://www.zomato.com/bangalore/omleterian-bt...
# ...                                                  ...
# 4801   https://www.zomato.com/bangalore/byg-brewski-b...
# 4944   https://www.zomato.com/bangalore/byg-brewski-b...
# 49170  https://www.zomato.com/bangalore/byg-brewski-b...
# 50059  https://www.zomato.com/bangalore/byg-brewski-b...
# 49627  https://www.zomato.com/bangalore/byg-brewski-b...
#
#                                                  address  \
# 27455  40/3, 7th Cross Road, Bhavani Nagar, Suddagunt...
# 27447  5, 4th Main Road Madiwala, Near Ayyappa Temple...
# 27315  3/5, Opposite Forum Mall, Hosur Cross Road, BT...
# ...

# %%
df.sort_values(['votes','location'],ascending=[True,False])  #mixed ascending and false
# Out:
#                                                      url  \
# 40423  https://www.zomato.com/bangalore/kerala-food-y...
# 40441  https://www.zomato.com/bangalore/biryani-food-...
# 40450  https://www.zomato.com/bangalore/alif-hotel-ye...
# 39637  https://www.zomato.com/bangalore/alif-hotel-ye...
# 39976  https://www.zomato.com/bangalore/biryani-food-...
# ...                                                  ...
# 4801   https://www.zomato.com/bangalore/byg-brewski-b...
# 4944   https://www.zomato.com/bangalore/byg-brewski-b...
# 49170  https://www.zomato.com/bangalore/byg-brewski-b...
# 50059  https://www.zomato.com/bangalore/byg-brewski-b...
# 49627  https://www.zomato.com/bangalore/byg-brewski-b...
#
#                                                  address  \
# 40423  38/1, 1st Main Road, Model Colony, Yeshwantpur...
# 40441    7th Cross, Triveni Road, Yeshwantpur, Bangalore
# 40450   TK Complex, Triveni Road, Yeshwantpur, Bangalore
# ...

# %% [markdown]
# # Drop Duplicates

# %%
# first to check duplicate row
df.duplicated().value_counts()   #no duplicated data row_wise
# Out:
# False    51717
# dtype: int64

# %%
df.duplicated(subset='location').value_counts()
# Out:
# True     51623
# False       94
# dtype: int64

# %%
#it mean we have unique 94 location 
df.location.unique()
# Out:
# array(['Sarjapur Road', 'Indiranagar', 'Koramangala 5th Block',
#        'Marathahalli', 'Old Airport Road', 'Koramangala 4th Block',
#        'Brigade Road', 'Church Street', 'Whitefield', 'HSR', 'BTM',
#        'Malleshwaram', 'Koramangala 7th Block', 'St. Marks Road',
#        'Jayanagar', 'New BEL Road', 'Cunningham Road',
#        'Koramangala 6th Block', 'MG Road', 'Basavanagudi', 'JP Nagar',
#        'Residency Road', 'Race Course Road', 'Lavelle Road',
#        'Koramangala 1st Block', 'Kammanahalli', 'Bannerghatta Road',
#        'Sahakara Nagar', 'Bellandur', 'Frazer Town',
#        'Koramangala 3rd Block', 'RT Nagar', 'Banashankari', 'Rajajinagar',
#        'Kalyan Nagar', 'Brookefield', 'Vasanth Nagar', 'Richmond Road',
#        'Sadashiv Nagar', 'Infantry Road', 'Electronic City', 'Domlur',
#        'Shanti Nagar', 'Ulsoor', 'Jeevan Bhima Nagar', 'Vijay Nagar',
#        'East Bangalore', 'Basaveshwara Nagar',
# ...

# %%
len(df.location.unique())
# Out:
# 94

# %%
# to drop duplicate
df.drop_duplicates()
# Out:
#                                                      url  \
# 49170  https://www.zomato.com/bangalore/byg-brewski-b...
# 50059  https://www.zomato.com/bangalore/byg-brewski-b...
# 49627  https://www.zomato.com/bangalore/byg-brewski-b...
# 3921   https://www.zomato.com/bangalore/byg-brewski-b...
# 4801   https://www.zomato.com/bangalore/byg-brewski-b...
# ...                                                  ...
# 8130   https://www.zomato.com/bangalore/sai-canteen-w...
# 18449  https://www.zomato.com/bangalore/indish-flavou...
# 8125   https://www.zomato.com/bangalore/pk-dhaba-mara...
# 8124   https://www.zomato.com/bangalore/masale-daan-v...
# 12028  https://www.zomato.com/bangalore/machali-fraze...
#
#                                                  address  \
# 49170         Behind MK Retail, Sarjapur Road, Bangalore
# 50059         Behind MK Retail, Sarjapur Road, Bangalore
# 49627         Behind MK Retail, Sarjapur Road, Bangalore
# ...

# %%
df.drop_duplicates(subset='location')
# Out:
#                                                      url  \
# 49170  https://www.zomato.com/bangalore/byg-brewski-b...
# 18643  https://www.zomato.com/bangalore/toit-indirana...
# 36668  https://www.zomato.com/bangalore/truffles-kora...
# 41525  https://www.zomato.com/bangalore/abs-absolute-...
# 46095  https://www.zomato.com/bangalore/big-pitcher-a...
# ...                                                  ...
# 26433  https://www.zomato.com/bangalore/the-bridge-wa...
# 46315  https://www.zomato.com/bangalore/ayodhya-food-...
# 47155  https://www.zomato.com/bangalore/karnataka-bri...
# 46752  https://www.zomato.com/bangalore/the-happy-veg...
# 24419  https://www.zomato.com/bangalore/red-savina-ja...
#
#                                                  address  \
# 49170         Behind MK Retail, Sarjapur Road, Bangalore
# 18643  298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# 36668  28, 4th 'B' Cross, Koramangala 5th Block, Bang...
# ...

# %%
df.drop_duplicates(subset='location',keep='first')   #  keep{‘first’, ‘last’, False},
# Out:
#                                                      url  \
# 49170  https://www.zomato.com/bangalore/byg-brewski-b...
# 18643  https://www.zomato.com/bangalore/toit-indirana...
# 36668  https://www.zomato.com/bangalore/truffles-kora...
# 41525  https://www.zomato.com/bangalore/abs-absolute-...
# 46095  https://www.zomato.com/bangalore/big-pitcher-a...
# ...                                                  ...
# 26433  https://www.zomato.com/bangalore/the-bridge-wa...
# 46315  https://www.zomato.com/bangalore/ayodhya-food-...
# 47155  https://www.zomato.com/bangalore/karnataka-bri...
# 46752  https://www.zomato.com/bangalore/the-happy-veg...
# 24419  https://www.zomato.com/bangalore/red-savina-ja...
#
#                                                  address  \
# 49170         Behind MK Retail, Sarjapur Road, Bangalore
# 18643  298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# 36668  28, 4th 'B' Cross, Koramangala 5th Block, Bang...
# ...

# %%
#multiple subset drop
df.drop_duplicates(subset=['location','listed_in(city)'],keep='first')   # and operation between subsets
# Out:
#                                                      url  \
# 49170  https://www.zomato.com/bangalore/byg-brewski-b...
# 3921   https://www.zomato.com/bangalore/byg-brewski-b...
# 18643  https://www.zomato.com/bangalore/toit-indirana...
# 36668  https://www.zomato.com/bangalore/truffles-kora...
# 33913  https://www.zomato.com/bangalore/truffles-kora...
# ...                                                  ...
# 30186  https://www.zomato.com/bangalore/my-tea-house-...
# 8203   https://www.zomato.com/bangalore/maza-e-hind-b...
# 42432  https://www.zomato.com/bangalore/house-of-cand...
# 18480  https://www.zomato.com/bangalore/cks-bakery-ci...
# 42626  https://www.zomato.com/bangalore/chawlas-2-onl...
#
#                                                  address  \
# 49170         Behind MK Retail, Sarjapur Road, Bangalore
# 3921          Behind MK Retail, Sarjapur Road, Bangalore
# 18643  298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# ...

# %% [markdown]
# # Group by

# %%
df.groupby('location')

# %%
loc=df.groupby('location')

# %%
len(loc)
# Out:
# 93

# %%
loc.size().sort_values()
# Out:
# location
# Peenya                      1
# Rajarajeshwari Nagar        2
# Jakkur                      3
# Yelahanka                   6
# West Bangalore              6
#                          ...
# Whitefield               2144
# JP Nagar                 2235
# Koramangala 5th Block    2504
# HSR                      2523
# BTM                      5124
# Length: 93, dtype: int64

# %%
df.location.value_counts().sort_values()
# Out:
# Peenya                      1
# Rajarajeshwari Nagar        2
# Jakkur                      3
# West Bangalore              6
# Yelahanka                   6
#                          ...
# Whitefield               2144
# JP Nagar                 2235
# Koramangala 5th Block    2504
# HSR                      2523
# BTM                      5124
# Name: location, Length: 93, dtype: int64

# %%
loc.first()         #every groups first value
# Out:
#                                                                  url  \
# location
# BTM                https://www.zomato.com/bangalore/abs-absolute-...
# Banashankari       https://www.zomato.com/bangalore/onesta-banash...
# Banaswadi          https://www.zomato.com/bangalore/saffron-veget...
# Bannerghatta Road  https://www.zomato.com/bangalore/empire-restau...
# Basavanagudi       https://www.zomato.com/bangalore/vidyarthi-bha...
# ...                                                              ...
# West Bangalore     https://www.zomato.com/bangalore/freshmenu-raj...
# Whitefield         https://www.zomato.com/bangalore/biergarten-wh...
# Wilson Garden      https://www.zomato.com/bangalore/dominos-pizza...
# Yelahanka          https://www.zomato.com/bangalore/chetas-kitche...
# Yeshwantpur        https://www.zomato.com/bangalore/new-agarwal-b...
#
#                                                              address  \
# location
# ...

# %%
loc.last()
# Out:
#                                                                  url  \
# location
# BTM                https://www.zomato.com/bangalore/hotel-vkm-btm...
# Banashankari       https://www.zomato.com/bangalore/my-tea-house-...
# Banaswadi          https://www.zomato.com/bangalore/al-baik-kabab...
# Bannerghatta Road  https://www.zomato.com/bangalore/cakeport-bann...
# Basavanagudi       https://www.zomato.com/bangalore/sugar-stars-c...
# ...                                                              ...
# West Bangalore     https://www.zomato.com/bangalore/garden-city-m...
# Whitefield         https://www.zomato.com/bangalore/sai-canteen-w...
# Wilson Garden      https://www.zomato.com/bangalore/house-of-tast...
# Yelahanka          https://www.zomato.com/bangalore/red-chillies-...
# Yeshwantpur        https://www.zomato.com/bangalore/malabar-treat...
#
#                                                              address  \
# location
# ...

# %%
loc.groups
# Out:
# {'BTM': [37099, 21279, 23587, 21770, 19393, 8260, 10389, 37101, 32551, 31672, 28919, 26520, 34758, 34426, 29671, 32133, 26853, 35188, 19709, 29299, 9181, 8262, 10391, 2650, 37118, 32357, 34990, 34437, 29453, 21324, 28952, 31689, 26747, 19609, 8490, 10404, 2596, 37107, 34429, 26622, 35521, 27138, 34846, 29983, 32846, 28929, 31675, 32226, 19995, 10394, 8901, 8299, 2790, 31677, 32522, 37110, 34431, 35159, 29599, 21308, 28935, 26926, 19779, 10395, 8593, 2683, 37111, 34879, 31676, 32248, 29357, 26645, 19494, 21844, 10397, 8714, 10198, 34870, 32242, 29348, 31698, 37143, 35012, 32374, 29481, 10546, 9011, 22427, 27359, 26639, 20237, 19486, 21839, 37649, 8399, 15879, 1940, 37103, 922, 37590, ...], 'Banashankari': [19586, 2584, 7, 44, 557, 21314, 19660, 465, 560, 2625, 3474, 20167, 571, 2612, 3493, 37, 21364, 20664, 3519, 54, 3083, 636, 855, 561, 3740, 3485, 19849, 2717, 2490, 577, 503, 3242, 2, 474, 3505, 14, 2520, 21392, 20291, 22472, 3534, 2920, 554, 487, 3061, 3739, 856, 3482, 562, 67, 209
# ...

# %%
loc.get_group('Yeshwantpur')        #to get particular group values
# Out:
#                                                      url  \
# 44016  https://www.zomato.com/bangalore/new-agarwal-b...
# 39842  https://www.zomato.com/bangalore/chandrappa-ho...
# 44234  https://www.zomato.com/bangalore/chandrappa-ho...
# 39465  https://www.zomato.com/bangalore/new-agarwal-b...
# 44697  https://www.zomato.com/bangalore/new-golden-em...
# ...                                                  ...
# 40450  https://www.zomato.com/bangalore/alif-hotel-ye...
# 39637  https://www.zomato.com/bangalore/alif-hotel-ye...
# 39976  https://www.zomato.com/bangalore/biryani-food-...
# 44352  https://www.zomato.com/bangalore/ruchi-curry-p...
# 44685  https://www.zomato.com/bangalore/malabar-treat...
#
#                                                  address                 name  \
# 44016  333, MSR Road, Gokul Extension, Mathikere, Yes...   New Agarwal Bhavan
# 39842  40/4, 15th Main, MSR Industrial Estate Road, M...     Chandrappa Hotel
# ...

# %%
loc.sum()
# Out:
#                     votes
# location
# BTM                619376
# Banashankari       162374
# Banaswadi           35657
# Bannerghatta Road  219077
# Basavanagudi        94919
# ...                   ...
# West Bangalore       1110
# Whitefield         466829
# Wilson Garden        7341
# Yelahanka             189
# Yeshwantpur          6980
#
# [93 rows x 1 columns]

# %%
loc['book_table'].value_counts().head(10).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='book_table'>

# %% [markdown]
# # is in function

# %%
listed=df['listed_in(city)'].value_counts()

# %%
listed_location_=listed.index.tolist()

# %%
listed_location_
# Out:
# ['BTM',
#  'Koramangala 7th Block',
#  'Koramangala 5th Block',
#  'Koramangala 4th Block',
#  'Koramangala 6th Block',
#  'Jayanagar',
#  'JP Nagar',
#  'Indiranagar',
#  'Church Street',
#  'MG Road',
#  'Brigade Road',
#  'Lavelle Road',
#  'HSR',
#  'Marathahalli',
#  'Residency Road',
#  'Whitefield',
#  'Bannerghatta Road',
#  'Brookefield',
#  'Old Airport Road',
#  'Kammanahalli',
#  'Kalyan Nagar',
#  'Basavanagudi',
#  'Sarjapur Road',
#  'Electronic City',
#  'Bellandur',
#  'Frazer Town',
#  'Malleshwaram',
#  'Rajajinagar',
#  'Banashankari',
#  'New BEL Road']

# %%
both_loc_same=df[df['location'].isin(listed_location_)]

# %%
#dataset where both location and listed city are same 
both_loc_same
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51710  https://www.zomato.com/bangalore/topsy-turvey-...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# # Merge

# %%
#must be merge if there is common relation between two dataset

# %%
#df.merge(second_dataframe,how='inner',left_on=.....,right_on=.....)

# %% [markdown]
# # reset index
# reset index is used to convert series to dataframe
# reset_index()

# %%
df.groupby(['location','listed_in(city)'])['votes'].sum().reset_index()
# Out:
#         location    listed_in(city)   votes
# 0            BTM                BTM  132473
# 1            BTM  Bannerghatta Road   29941
# 2            BTM       Basavanagudi   11520
# 3            BTM          Bellandur       0
# 4            BTM       Brigade Road       0
# ..           ...                ...     ...
# 702    Yelahanka       Malleshwaram      20
# 703    Yelahanka       New BEL Road     169
# 704  Yeshwantpur       Malleshwaram    3708
# 705  Yeshwantpur       New BEL Road    3127
# 706  Yeshwantpur        Rajajinagar     145
#
# [707 rows x 3 columns]

# %% [markdown]
# # Pvoit Table

# %%
df.head(1)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
#
#                                              address   name online_order  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...  Jalsa          Yes
#
#   book_table   rate  votes                           phone      location  \
# 0        Yes  4.1/5    775  080 42297555\r\n+91 9743772233  Banashankari
#
#        rest_type                                         dish_liked  \
# 0  Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari

# %%
#location vise overall voting sum on basis of book table 
df.pivot_table(index='location',columns='book_table',values='votes',aggfunc='sum')
# Out:
# book_table               No       Yes
# location
# BTM                432939.0  186437.0
# Banashankari       115032.0   47342.0
# Banaswadi           32457.0    3200.0
# Bannerghatta Road  108307.0  110770.0
# Basavanagudi        88824.0    6095.0
# ...                     ...       ...
# West Bangalore       1110.0       NaN
# Whitefield         221689.0  245140.0
# Wilson Garden        6649.0     692.0
# Yelahanka             189.0       NaN
# Yeshwantpur          6764.0     216.0
#
# [93 rows x 2 columns]

# %%
df.pivot_table(index='location',columns='rest_type',values='votes',aggfunc='sum')
# Out:
# rest_type          Bakery  Bakery, Beverage Shop  Bakery, Cafe  \
# location
# BTM                1525.0                    NaN           NaN
# Banashankari        530.0                    NaN           NaN
# Banaswadi           358.0                    NaN           NaN
# Bannerghatta Road   614.0                    NaN           NaN
# Basavanagudi       1240.0                    NaN           NaN
# ...                   ...                    ...           ...
# West Bangalore        NaN                    NaN           NaN
# Whitefield         1189.0                    NaN        3989.0
# Wilson Garden        38.0                    NaN           NaN
# Yelahanka             NaN                    NaN           NaN
# Yeshwantpur          61.0                    NaN          22.0
#
# rest_type          Bakery, Dessert Parlor  Bakery, Food Court  Bakery, Kiosk  \
# location
# BTM                                   NaN                 NaN            NaN
# ...

# %%
df.pivot_table(index='location',columns='listed_in(type)',values='votes',aggfunc='sum')
# Out:
# listed_in(type)     Buffet    Cafes  Delivery  Desserts  Dine-out  \
# location
# BTM                43073.0  15345.0  343362.0   12086.0  195195.0
# Banashankari        5044.0   9150.0   78952.0    7996.0   57010.0
# Banaswadi              NaN    808.0   18306.0     743.0   15128.0
# Bannerghatta Road  17564.0   1924.0  105660.0    4456.0   69525.0
# Basavanagudi         967.0   4061.0   38090.0    3320.0   47535.0
# ...                    ...      ...       ...       ...       ...
# West Bangalore         NaN      NaN    1110.0       NaN       0.0
# Whitefield         13873.0  14740.0  159113.0   14480.0  177263.0
# Wilson Garden        224.0      0.0    4629.0      56.0    2018.0
# Yelahanka              NaN      NaN     101.0       NaN      88.0
# Yeshwantpur           19.0      NaN    5951.0      38.0     958.0
#
# listed_in(type)    Drinks & nightlife  Pubs and bars
# location
# BTM                            6655.0         3660.0
# ...

# %% [markdown]
# # corr ,cov , var"
# for numerical columns
#
# corr for relation between two columns
#
# cov variance between two columns
#
# var varianve between inside a column values

# %%
df=pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df.corr()
# Out:
#                age       bmi  children  expenses
# age       1.000000  0.109341  0.042469  0.299008
# bmi       0.109341  1.000000  0.012645  0.198576
# children  0.042469  0.012645  1.000000  0.067998
# expenses  0.299008  0.198576  0.067998  1.000000

# %%
df.corr()['expenses']
# Out:
# age         0.299008
# bmi         0.198576
# children    0.067998
# expenses    1.000000
# Name: expenses, dtype: float64

# %%
df.cov()
# Out:
#                    age           bmi    children      expenses
# age         197.401387      9.368560    0.719303  5.087480e+04
# bmi           9.368560     37.190265    0.092958  1.466515e+04
# children      0.719303      0.092958    1.453213  9.926742e+02
# expenses  50874.802133  14665.149703  992.674243  1.466524e+08

# %%
df.cov()['expenses']
# Out:
# age         5.087480e+04
# bmi         1.466515e+04
# children    9.926742e+02
# expenses    1.466524e+08
# Name: expenses, dtype: float64

# %%
df.age.var()
# Out:
# 197.40138665754424

# %%
df.var()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_9340/1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# age         1.974014e+02
# bmi         3.719027e+01
# children    1.453213e+00
# expenses    1.466524e+08
# dtype: float64

# %%
df.expenses.var()
# Out:
# 146652372.22581673

# %%
df.corr(method='kendall')    #method{‘pearson’, ‘kendall’, ‘spearman’} or callable')
# Out:
#                age       bmi  children  expenses
# age       1.000000  0.073390  0.043253  0.475302
# bmi       0.073390  1.000000  0.011558  0.082653
# children  0.043253  0.011558  1.000000  0.103107
# expenses  0.475302  0.082653  0.103107  1.000000

# %%
df.corr(method='pearson')
# Out:
#                age       bmi  children  expenses
# age       1.000000  0.109341  0.042469  0.299008
# bmi       0.109341  1.000000  0.012645  0.198576
# children  0.042469  0.012645  1.000000  0.067998
# expenses  0.299008  0.198576  0.067998  1.000000

# %%
df.corr(method='spearman')
# Out:
#                age       bmi  children  expenses
# age       1.000000  0.107692  0.056992  0.534392
# bmi       0.107692  1.000000  0.015589  0.119419
# children  0.056992  0.015589  1.000000  0.133339
# expenses  0.534392  0.119419  0.133339  1.000000

# %% [markdown]
# # rename columns

# %%
df=pd.read_csv('insurance.csv')

# %%
df.rename(columns={'age':'Age','bmi':'Bmi'})    #for permanent inplace=True
# Out:
#       Age     sex   Bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %% [markdown]
# # set index
# df.set_index(column name)   inplace=True for permanent

# %% [markdown]
# # missing values
# dropna

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df=pd.read_csv('train.csv')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dropna().shape #row drop bydefault axis=0
# Out:
# (183, 12)

# %%
df.dropna(how='all').shape
# Out:
# (891, 12)

# %%
df.dropna(axis=1).shape   #columns drop
# Out:
# (891, 9)

# %%
# for single row data drop

# %%
df.dropna(subset=['Embarked']).shape
# Out:
# (889, 12)

# %%
df.dropna(subset=['Embarked','Age']).shape       # or operation on embarked and age
# Out:
# (712, 12)

# %% [markdown]
# # fill na method

# %%
df.Age.fillna(0)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     0.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.Age.fillna(method='ffill')        #method{‘backfill’, ‘bfill’, ‘pad’, ‘ffill’, None},
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.fillna(method='ffill')    #to all columns
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#filling with mean value
df.Age.fillna(int(np.mean(df.Age)))
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    29.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.Age.fillna(int(df.Age.mean()))
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    29.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
